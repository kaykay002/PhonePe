# %%
import os

# %%
import psycopg2

# %%
import pandas as pd
import json

# %%
#aggregate_state_list

path="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list


column={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for state in Agg_state_list:
    current_state=path+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            AS=json.load(data)
            
            for i in AS['data']['transactionData']:
              Name=i['name']
              count=i['paymentInstruments'][0]['count']
              amount=i['paymentInstruments'][0]['amount']
              column['Transaction_type'].append(Name)
              column['Transaction_count'].append(count)
              column['Transaction_amount'].append(amount)
              column['State'].append(state)
              column['Year'].append(year)
              column['Quater'].append(int(file.strip(".json")))

Agg_Transaction=pd.DataFrame(column)
Agg_Transaction["State"]=Agg_Transaction["State"].str.replace("-", " ")
Agg_Transaction["State"]=Agg_Transaction["State"].str.title()
Agg_Transaction["State"]=Agg_Transaction["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Agg_Transaction
# Out:
#                           State  Year  Quater          Transaction_type  \
# 0     Andaman & Nicobar Islands  2018       1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018       1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018       1         Merchant payments
# 3     Andaman & Nicobar Islands  2018       1        Financial Services
# 4     Andaman & Nicobar Islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 4309                West Bengal  2023       4         Merchant payments
# 4310                West Bengal  2023       4     Peer-to-peer payments
# 4311                West Bengal  2023       4  Recharge & bill payments
# 4312                West Bengal  2023       4        Financial Services
# 4313                West Bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
#aggregate_user_list

path2="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/aggregated/user/country/india/state/"
Agg_user_list=os.listdir(path2)


column2={'State':[], 'Year':[],'Quater':[],'Brand':[], 'Transaction_count':[], 'Percentage':[]}


for state in Agg_state_list:
    current_state=path2+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            AU=json.load(data)

            try:
                for i in AU['data']['usersByDevice']:
                    brand=i['brand']
                    count=i['count']
                    percentage=i['percentage']
                    column2['Brand'].append(brand)
                    column2['Transaction_count'].append(count)
                    column2['Percentage'].append(percentage)
                    column2['State'].append(state)
                    column2['Year'].append(year)
                    column2['Quater'].append(int(file.strip(".json")))
            except:
                pass

Agg_User=pd.DataFrame(column2)

Agg_User["State"]=Agg_User["State"].str.replace("-", " ")
Agg_User["State"]=Agg_User["State"].str.title()
Agg_User["State"]=Agg_User["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Agg_User
# Out:
#                           State  Year  Quater    Brand  Transaction_count  \
# 0     Andaman & Nicobar Islands  2018       1   Xiaomi               1665
# 1     Andaman & Nicobar Islands  2018       1  Samsung               1445
# 2     Andaman & Nicobar Islands  2018       1     Vivo                982
# 3     Andaman & Nicobar Islands  2018       1     Oppo                501
# 4     Andaman & Nicobar Islands  2018       1  OnePlus                332
# ...                         ...   ...     ...      ...                ...
# 6727                West Bengal  2022       1   Lenovo             330017
# 6728                West Bengal  2022       1  Infinix             284678
# 6729                West Bengal  2022       1     Asus             280347
# 6730                West Bengal  2022       1    Apple             277752
# 6731                West Bengal  2022       1   Others            2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
#map_transaction_list

path3="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/map/transaction/hover/country/india/state/"
Map_trans_list=os.listdir(path3)


column3={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Transaction_count':[], 'Transaction_amount':[]}


for state in Map_trans_list:
    current_state=path3+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            MT=json.load(data)

            
            for i in MT['data']['hoverDataList']:
                name=i['name']
                count=i['metric'][0]['count']
                amount=i['metric'][0]['amount']
                column3['Districts'].append(name)
                column3['Transaction_count'].append(count)
                column3['Transaction_amount'].append(amount)
                column3['State'].append(state)
                column3['Year'].append(year)
                column3['Quater'].append(int(file.strip(".json")))
           

Map_Transactions=pd.DataFrame(column3)


Map_Transactions["State"]=Map_Transactions["State"].str.replace("-", " ")
Map_Transactions["State"]=Map_Transactions["State"].str.title()
Map_Transactions["State"]=Map_Transactions["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Map_Transactions
# Out:
#                            State  Year  Quater  \
# 0      Andaman & Nicobar Islands  2018       1
# 1      Andaman & Nicobar Islands  2018       1
# 2      Andaman & Nicobar Islands  2018       1
# 3      Andaman & Nicobar Islands  2018       2
# 4      Andaman & Nicobar Islands  2018       2
# ...                          ...   ...     ...
# 17559                West Bengal  2023       4
# 17560                West Bengal  2023       4
# 17561                West Bengal  2023       4
# 17562                West Bengal  2023       4
# 17563                West Bengal  2023       4
#
#                                Districts  Transaction_count  \
# 0      north and middle andaman district                442
# 1                 south andaman district               5688
# 2                      nicobars district                528
# 3      north and middle andaman district                825
# 4                 south andaman district               9395
# ...

# %%
#map_user_list

path4="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/map/user/hover/country/india/state/"
Map_user_list=os.listdir(path4)


column4={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Registered_Users':[], 'App_Opens':[]}


for state in Map_user_list:
    current_state=path4+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            MU=json.load(data)

            
            for i in MU["data"]["hoverData"].items():
                name=i[0]
                registeredUsers=i[1]['registeredUsers']
                appOpens=i[1]['appOpens']
                column4['Districts'].append(name)
                column4['Registered_Users'].append(registeredUsers)
                column4['App_Opens'].append(appOpens)
                column4['State'].append(state)
                column4['Year'].append(year)
                column4['Quater'].append(int(file.strip(".json")))
           

Map_User=pd.DataFrame(column4)


Map_User["State"]=Map_User["State"].str.replace("-", " ")
Map_User["State"]=Map_User["State"].str.title()
Map_User["State"]=Map_User["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Map_User
# Out:
#                            State  Year  Quater  \
# 0      Andaman & Nicobar Islands  2018       1
# 1      Andaman & Nicobar Islands  2018       1
# 2      Andaman & Nicobar Islands  2018       1
# 3      Andaman & Nicobar Islands  2018       2
# 4      Andaman & Nicobar Islands  2018       2
# ...                          ...   ...     ...
# 17563                West Bengal  2023       4
# 17564                West Bengal  2023       4
# 17565                West Bengal  2023       4
# 17566                West Bengal  2023       4
# 17567                West Bengal  2023       4
#
#                                Districts  Registered_Users  App_Opens
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %%
#aggregate_insurance

path5="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/aggregated/insurance/country/india/state/"
Agg_insurance_list=os.listdir(path5)

column5={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for state in Agg_insurance_list:
    current_state=path5+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            AI=json.load(data)
            
            for i in AI['data']['transactionData']:
              Name=i['name']
              count=i['paymentInstruments'][0]['count']
              amount=i['paymentInstruments'][0]['amount']
              column5['Transaction_type'].append(Name)
              column5['Transaction_count'].append(count)
              column5['Transaction_amount'].append(amount)
              column5['State'].append(state)
              column5['Year'].append(year)
              column5['Quater'].append(int(file.strip(".json")))

Agg_insurance=pd.DataFrame(column5)


Agg_insurance["State"]=Agg_insurance["State"].str.replace("-", " ")
Agg_insurance["State"]=Agg_insurance["State"].str.title()
Agg_insurance["State"]=Agg_insurance["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Agg_insurance
# Out:
#                          State  Year  Quater Transaction_type  \
# 0    Andaman & Nicobar Islands  2020       2        Insurance
# 1    Andaman & Nicobar Islands  2020       3        Insurance
# 2    Andaman & Nicobar Islands  2020       4        Insurance
# 3    Andaman & Nicobar Islands  2021       1        Insurance
# 4    Andaman & Nicobar Islands  2021       2        Insurance
# ..                         ...   ...     ...              ...
# 533                West Bengal  2022       4        Insurance
# 534                West Bengal  2023       1        Insurance
# 535                West Bengal  2023       2        Insurance
# 536                West Bengal  2023       3        Insurance
# 537                West Bengal  2023       4        Insurance
#
#      Transaction_count  Transaction_amount
# 0                    6              1360.0
# 1                   41             15380.0
# 2                  124            157975.0
# 3                  225            244266.0
# ...

# %%
#map_insurance_list

path6="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/map/insurance/hover/country/india/state/"
Map_insurance_list=os.listdir(path6)


column6={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Transaction_count':[], 'Transaction_amount':[]}


for state in Map_insurance_list:
    current_state=path6+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            MI=json.load(data)

            
            for i in MI['data']['hoverDataList']:
                name=i['name']
                count=i['metric'][0]['count']
                amount=i['metric'][0]['amount']
                column6['Districts'].append(name)
                column6['Transaction_count'].append(count)
                column6['Transaction_amount'].append(amount)
                column6['State'].append(state)
                column6['Year'].append(year)
                column6['Quater'].append(int(file.strip(".json")))
           

Map_Insurance=pd.DataFrame(column6)

Map_Insurance["State"]=Map_Insurance["State"].str.replace("-", " ")
Map_Insurance["State"]=Map_Insurance["State"].str.title()
Map_Insurance["State"]=Map_Insurance["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Map_Insurance
# Out:
#                            State  Year  Quater  \
# 0      Andaman & Nicobar Islands  2020       2
# 1      Andaman & Nicobar Islands  2020       2
# 2      Andaman & Nicobar Islands  2020       3
# 3      Andaman & Nicobar Islands  2020       3
# 4      Andaman & Nicobar Islands  2020       3
# ...                          ...   ...     ...
# 10823                West Bengal  2023       4
# 10824                West Bengal  2023       4
# 10825                West Bengal  2023       4
# 10826                West Bengal  2023       4
# 10827                West Bengal  2023       4
#
#                                Districts  Transaction_count  \
# 0                 south andaman district                  3
# 1                      nicobars district                  3
# 2      north and middle andaman district                  1
# 3                 south andaman district                 35
# 4                      nicobars district                  5
# ...

# %%
#top_insurance

path7="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/top/insurance/country/india/state/"
Top_insurance_list=os.listdir(path7)

column7={'State':[], 'Year':[],'Quater':[],'Pincode':[], 'Transaction_Count':[], 'Transaction_Amount':[]}

for state in Top_insurance_list:
    current_state=path7+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            TI=json.load(data)
            
            for i in TI["data"]["pincodes"]:
                entityName=i["entityName"]
                count=i["metric"]['count']
                amount=i["metric"]["amount"]
                column7['Pincode'].append(entityName)
                column7['Transaction_Count'].append(count)
                column7['Transaction_Amount'].append(amount)
                column7['State'].append(state)
                column7['Year'].append(year)
                column7['Quater'].append(int(file.strip(".json")))

Top_insurance=pd.DataFrame(column7)

Top_insurance["State"]=Top_insurance["State"].str.replace("-", " ")
Top_insurance["State"]=Top_insurance["State"].str.title()
Top_insurance["State"]=Top_insurance["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Top_insurance
# Out:
#                           State  Year  Quater Pincode  Transaction_Count  \
# 0     Andaman & Nicobar Islands  2020       2  744301                  3
# 1     Andaman & Nicobar Islands  2020       2  744104                  2
# 2     Andaman & Nicobar Islands  2020       2  744101                  1
# 3     Andaman & Nicobar Islands  2020       3  744112                  9
# 4     Andaman & Nicobar Islands  2020       3  744105                  7
# ...                         ...   ...     ...     ...                ...
# 5244                West Bengal  2023       4  700135                556
# 5245                West Bengal  2023       4  700091                535
# 5246                West Bengal  2023       4  700015                521
# 5247                West Bengal  2023       4  700059                518
# 5248                West Bengal  2023       4  711102                517
#
#       Transaction_Amount
# 0                  565.0
# 1                  513.0
# ...

# %%
#top_transaction

path8="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/top/transaction/country/india/state/"
Top_transaction_list=os.listdir(path8)

column8={'State':[], 'Year':[],'Quater':[],'Pincode':[], 'Transaction_Count':[], 'Transaction_Amount':[]}

for state in Top_transaction_list:
    current_state=path8+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            TT=json.load(data)
            
            for i in TT["data"]["pincodes"]:
                entityName=i["entityName"]
                count=i["metric"]['count']
                amount=i["metric"]["amount"]
                column8['Pincode'].append(entityName)
                column8['Transaction_Count'].append(count)
                column8['Transaction_Amount'].append(amount)
                column8['State'].append(state)
                column8['Year'].append(year)
                column8['Quater'].append(int(file.strip(".json")))

Top_transaction=pd.DataFrame(column8)

Top_transaction["State"]=Top_transaction["State"].str.replace("-", " ")
Top_transaction["State"]=Top_transaction["State"].str.title()
Top_transaction["State"]=Top_transaction["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Top_transaction
# Out:
#                           State  Year  Quater Pincode  Transaction_Count  \
# 0     Andaman & Nicobar Islands  2018       1  744101               1622
# 1     Andaman & Nicobar Islands  2018       1  744103               1223
# 2     Andaman & Nicobar Islands  2018       1  744102                969
# 3     Andaman & Nicobar Islands  2018       1  744105                685
# 4     Andaman & Nicobar Islands  2018       1  744104                340
# ...                         ...   ...     ...     ...                ...
# 8562                West Bengal  2023       4  721301            4133775
# 8563                West Bengal  2023       4  700001            3983241
# 8564                West Bengal  2023       4  732125            3950411
# 8565                West Bengal  2023       4  700039            3742452
# 8566                West Bengal  2023       4  700014            3652710
#
#       Transaction_Amount
# 0           2.769298e+06
# 1           2.238042e+06
# ...

# %%
#top_user

path9="C:/Users/Admin/Desktop/GUVI/Capstone Project/PhonePe/pulse-master/data/top/user/country/india/state/"
Top_user_list=os.listdir(path9)

column9={'State':[], 'Year':[],'Quater':[],'Pincode':[], 'RegisteredUsers':[]}

for state in Top_user_list:
    current_state=path9+state+"/"
    Agg_year=os.listdir(current_state)
    
    for year in Agg_year:
        current_year=current_state+year+"/"
        Agg_year_list=os.listdir(current_year)
        
        for file in Agg_year_list:
            current_file=current_year+file
            data=open(current_file,"r")
            TU=json.load(data)
            
            for i in TU["data"]["pincodes"]:
                entityName=i["name"]
                registeredUsers=i["registeredUsers"]
                column9['Pincode'].append(entityName)
                column9['RegisteredUsers'].append(registeredUsers)
                column9['State'].append(state)
                column9['Year'].append(year)
                column9['Quater'].append(int(file.strip(".json")))

Top_User=pd.DataFrame(column9)

Top_User["State"]=Top_User["State"].str.replace("-", " ")
Top_User["State"]=Top_User["State"].str.title()
Top_User["State"]=Top_User["State"].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra & Nagar Haveli and Daman & Diu")

# %%
Top_User
# Out:
#                           State  Year  Quater Pincode  RegisteredUsers
# 0     Andaman & Nicobar Islands  2018       1  744103             1608
# 1     Andaman & Nicobar Islands  2018       1  744101             1108
# 2     Andaman & Nicobar Islands  2018       1  744105             1075
# 3     Andaman & Nicobar Islands  2018       1  744102             1006
# 4     Andaman & Nicobar Islands  2018       1  744104              272
# ...                         ...   ...     ...     ...              ...
# 8563                West Bengal  2023       4  700015           126663
# 8564                West Bengal  2023       4  742304           123320
# 8565                West Bengal  2023       4  721101           123088
# 8566                West Bengal  2023       4  700150           119283
# 8567                West Bengal  2023       4  700091           118578
#
# [8568 rows x 5 columns]

# %%
r

# %%
#Table creation in SQL #agg_transaction_table
#SQL Connection
#-------------------------------------------------------------------------------------

mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password=12345,
                      database="Phonepe_database",
                      port=5432)

cursor=mydb.cursor()

#-----------------------------------------------------------------------------------------
query2='''CREATE table if not exists Aggregate_Transaction(State varchar(300),
                                        Year int,
                                        Quarter int,
                                        Transaction_type varchar(300),
                                        Transaction_count bigint,
                                        Transaction_amount bigint)'''


cursor.execute(query2)
mydb.commit()

data_query2='''INSERT into Aggregate_Transaction(State,
                                               Year, 
                                               Quarter, 
                                               Transaction_type, 
                                               Transaction_count,
                                               Transaction_amount)
                                               
                                               values(%s,%s,%s,%s,%s,%s)'''

data2=Agg_Transaction.values.tolist()
cursor.executemany(data_query2,data2)
mydb.commit()

# %%
#Table creation in SQL #agg_user_table
mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password=12345,
                      database="Phonepe_database",
                      port=5432)

cursor=mydb.cursor()
#-----------------------------------------------------------------------------------------
query3='''CREATE table if not exists Aggregate_User(State varchar(300),
                                        Year int,
                                        Quarter int,
                                        Brand varchar(300),
                                        Transaction_count bigint,
                                        Percentage float)'''


cursor.execute(query3)
mydb.commit()

data_query3='''INSERT into Aggregate_User(State,
                                               Year, 
                                               Quarter, 
                                               Brand, 
                                               Transaction_count,
                                               Percentage)
                                               
                                               values(%s,%s,%s,%s,%s,%s)'''

data3=Agg_User.values.tolist()
cursor.executemany(data_query3,data3)
mydb.commit()

# %%
#Table creation in SQL #map_insurance_table
mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password=12345,
                      database="Phonepe_database",
                      port=5432)

cursor=mydb.cursor()
#-----------------------------------------------------------------------------------------
query4='''CREATE table if not exists Map_Insurance(State varchar(300),
                                        Year int,
                                        Quarter int,
                                        District varchar(500),
                                        Transaction_count bigint,
                                        Transaction_amount bigint)'''


cursor.execute(query4)
mydb.commit()

data_query4='''INSERT into Map_Insurance(State,
                                        Year, 
                                        Quarter, 
                                        District, 
                                        Transaction_count,
                                        Transaction_amount)
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''

data4=Map_Insurance.values.tolist()
cursor.executemany(data_query4,data4)
mydb.commit()

# %%
#Table creation in SQL #map_transaction_table
mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password=12345,
                      database="Phonepe_database",
                      port=5432)

cursor=mydb.cursor()
#-----------------------------------------------------------------------------------------
query5='''CREATE table if not exists Map_Transaction(State varchar(300),
                                        Year int,
                                        Quarter int,
                                        District varchar(500),
                                        Transaction_count bigint,
                                        Transaction_amount bigint)'''


cursor.execute(query5)
mydb.commit()

data_query5='''INSERT into Map_Transaction(State,
                                        Year, 
                                        Quarter, 
                                        District, 
                                        Transaction_count,
                                        Transaction_amount)
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''

data5=Map_Transactions.values.tolist()
cursor.executemany(data_query5,data5)
mydb.commit()

# %%
#Table creation in SQL #map_user_table
mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password=12345,
                      database="Phonepe_database",
                      port=5432)

cursor=mydb.cursor()
#-----------------------------------------------------------------------------------------
query6='''CREATE table if not exists Map_User(State varchar(300),
                                        Year int,
                                        Quarter int,
                                        District varchar(500),
                                        Registered_Users bigint,
                                        App_Opens bigint)'''


cursor.execute(query6)
mydb.commit()

data_query6='''INSERT into Map_User(State,
                                        Year, 
                                        Quarter, 
                                        District, 
                                        Registered_Users,
                                        App_Opens)
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''

data6=Map_User.values.tolist()
cursor.executemany(data_query6,data6)
mydb.commit()

# %%
#Table creation in SQL #top_insurance_table
mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password=12345,
                      database="Phonepe_database",
                      port=5432)

cursor=mydb.cursor()
#-----------------------------------------------------------------------------------------
query7='''CREATE table if not exists Top_Insurance(State varchar(300),
                                        Year int,
                                        Quarter int,
                                        Pincode bigint,
                                        Transaction_count bigint,
                                        Transaction_amount bigint)'''


cursor.execute(query7)
mydb.commit()

data_query7='''INSERT into Top_Insurance(State,
                                        Year, 
                                        Quarter, 
                                        Pincode, 
                                        Transaction_count,
                                        Transaction_amount)
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''

data7=Top_insurance.values.tolist()
cursor.executemany(data_query7,data7)
mydb.commit()

# %%
#Table creation in SQL #top_user_table
mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password=12345,
                      database="Phonepe_database",
                      port=5432)

cursor=mydb.cursor()
#-----------------------------------------------------------------------------------------
query9='''CREATE table if not exists Top_User(State varchar(300),
                                        Year int,
                                        Quarter int,
                                        Pincode int,
                                        RegisteredUsers bigint
                                        )'''


cursor.execute(query9)
mydb.commit()

data_query9='''INSERT into Top_User(State,
                                        Year, 
                                        Quarter, 
                                        Pincode, 
                                        RegisteredUsers
                                        )
                                        
                                        values(%s,%s,%s,%s,%s)'''

data9=Top_User.values.tolist()
cursor.executemany(data_query9,data9)
mydb.commit()

# %%
Top_User.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Pincode', 'RegisteredUsers'], dtype='object')
